# %%
import torch
import torchvision
import numpy as np

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader

# Importing all the required Libraries

# %%
# https://github.com/AquibPy/Pytorch/blob/master/MNIST%20Using%20ANN%20on%20GPU%20with%20Pytorch.ipynb

# The below code is added to transfer data from CPU to CUDA if CUDA is available

def get_default_device():
  """Pick GPU if available, else CPU"""
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')
device = get_default_device()
device

def to_device(data,device):
    if isinstance(data, (list,tuple)): #The isinstance() function returns True if the specified object is of the specified type, otherwise False.
        return [to_device(x,device) for x in data]
    return data.to(device,non_blocking=True)

# The below code is a wrapper around the data loader function to transfer all data points to the available device

class DeviceDataLoader(Dataset):
    def __init__(self,dl,device):
        self.dl = dl
        self.device = device
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl:
            yield to_device(b,self.device)

    
    def __len__(self):
        return len(self.dl)

# %%
# This block stores all the parameters to train the Neural Network

n_epochs = 3
batch_size_train = 10
batch_size_test = 1000
learning_rate = 0.01
momentum = 0.5
log_interval = 10

random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# %%
# We import the MNIST dataset using the DataLoader and store it in train and test 

train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('/files/', train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=True)

test_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('/files/', train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=True)

# %%
# We add random input to the neural network, that is being sent as one-hot encoded matrix. The 2 functions convert int to one-hot encoding and back to int.

def convert_to_one_hot_encoding(input_data, num_classes):
  one_hot = torch.nn.functional.one_hot(input_data, num_classes = num_classes)
  return one_hot

def convert_to_labels(input_data):
  output = torch.argmax(input_data, dim=1)
  return output

# %%
# This is a custom loss function created to calculate Mean squared error loss between the Y2 and the expected output

def complex_mse_loss(output, target):
  return (0.5*(output - target)**2).mean(dtype=torch.complex64)

# %%
# Creating Additional Train data
'''
We use this function to create the additional random input (x2) and y2 (which is the sum of x2 and output - y1). We first create a random tensor based on the 
training data size (x2). Next, we iterate through the MNIST data to access the input image (x1) and the digit value (y1). 

We do the necessary data massaging to get all the data at the same type.

We need to process this data simultaneously because our output y2 is dependent on output y1 from the MNIST dataset.
'''
def train_additional_data():
  size_additional_data = 60000
  batch_size_train = 10
  additional_input_data_x2 = torch.randint(0, 10, (size_additional_data,))
  additional_input_data_x2 = torch.tensor(additional_input_data_x2, dtype = torch.float32)

  additional_output_y1_intermediary = []
  image_data = torch.empty(0)
  for batch_idx, (data, target) in enumerate(train_loader):
    target = target.tolist()
    additional_output_y1_intermediary.append(target)
    y = data
    image_data = torch.cat([image_data, y], dim = 0)

  additional_output_y1_intermediary_flat_list = [item for sublist in additional_output_y1_intermediary for item in sublist]
  additional_output_y1 = torch.tensor(additional_output_y1_intermediary_flat_list, dtype = torch.float32)
  additional_output_y2 = torch.add(additional_input_data_x2, additional_output_y1)
  return image_data, additional_output_y1, additional_input_data_x2, additional_output_y2

# Creating Additional Test data
def test_additional_data():
  size_additional_data = 10000
  batch_size_test = 1000
  additional_input_data_x2 = torch.randint(0, 10, (size_additional_data,))
  additional_input_data_x2 = torch.tensor(additional_input_data_x2, dtype = torch.float32)

  additional_output_y1_intermediary = []
  image_data = torch.empty(0)
  for batch_idx, (data, target) in enumerate(test_loader):
    target = target.tolist()
    additional_output_y1_intermediary.append(target)
    y = data
    image_data = torch.cat([image_data, y], dim = 0)

  additional_output_y1_intermediary_flat_list = [item for sublist in additional_output_y1_intermediary for item in sublist]
  additional_output_y1 = torch.tensor(additional_output_y1_intermediary_flat_list, dtype = torch.float32)
  additional_output_y2 = torch.add(additional_input_data_x2, additional_output_y1)
  return image_data, additional_output_y1, additional_input_data_x2, additional_output_y2

# %%
train_image_data, train_y1, train_additional_input_data_x2, train_additional_output_y2   = train_additional_data() # Converting the function to tensors
additional_train_loader = torch.utils.data.DataLoader(list(zip(train_image_data, train_y1, train_additional_input_data_x2, train_additional_output_y2)),batch_size=batch_size_train, shuffle=False)
# We turn shuffle = False because we want the y2 to be aligned to the right y1 for a given image. Similarly we do this for the test data set.
additional_train_loader = DeviceDataLoader(additional_train_loader,device)
# Out:
# <ipython-input-35-5c98dd0f4bac>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   additional_input_data_x2 = torch.tensor(additional_input_data_x2, dtype = torch.float32)

# %%
test_image_data, test_y1, test_additional_input_data_x2, test_additional_output_y2   = test_additional_data()
additional_test_loader = torch.utils.data.DataLoader(list(zip(test_image_data, test_y1, test_additional_input_data_x2, test_additional_output_y2)),batch_size=batch_size_test, shuffle=False)
additional_test_loader = DeviceDataLoader(additional_test_loader,device)
# Out:
# <ipython-input-35-5c98dd0f4bac>:26: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   additional_input_data_x2 = torch.tensor(additional_input_data_x2, dtype = torch.float32)

# %%
# https://stackoverflow.com/questions/51700729/how-to-construct-a-network-with-two-inputs-in-pytorch

# We are introducing the x2 which is the 2nd input only after the full conv is done and we are flattening our image and extracting all the required info from image.

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5) # self.conv1 = nn.Conv2d(1, 10, kernel_size=5) is a line of code in PyTorch that creates a 2D convolutional layer with 1 input channel, 10 output channels, and a 5x5 kernel size.
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5) # self.conv2 = nn.Conv2d(10, 20, kernel_size=5) is a line of code in PyTorch that creates a 2D convolutional layer with 10 input channels, 20 output channels, and a 5x5 kernel size.
        self.conv2_drop = nn.Dropout2d() # self.conv2_drop = nn.Dropout2d() is a line of code in PyTorch that creates a 2D dropout layer.
        self.fc1 = nn.Linear(320, 50) #  self.fc1 = nn.Linear(320, 50) is a line of code in PyTorch that creates a fully connected layer with 320 input units and 50 output units.
        self.fc2 = nn.Linear(50, 10)
        self.fc3 = nn.Linear(20, 320) # Here we are taking the input of 20 because we convert the input x2 and y2 to 20 dimensions, to accommodate 1-20 values.
        self.fc4 = nn.Linear(50, 20)

    def forward(self, x, x2):
        x = F.relu(F.max_pool2d(self.conv1(x), 2)) # x = F.relu(F.max_pool2d(self.conv1(x), 2)) is a line of code in PyTorch that applies a 2x2 max pooling layer with ReLU activation to the output of a convolutional layer.
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2)) # x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2)) is a line of code in PyTorch that applies a 2x2 max pooling layer with ReLU activation to the output of a convolutional layer with dropout applied.
        x = x.view(-1, 320) # x = x.view(-1, 320) is a line of code in PyTorch that reshapes a tensor into a 2D matrix with 320 columns.
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training) # Dropout is a regularization technique used in machine learning to reduce overfitting by randomly setting some of the input units to 0 during the forward pass.
        x = self.fc2(x)
        f = F.relu(self.fc3(x2)) # We take a 20 dimension one-hot encoded vector and pass it into the Neural network and convert it to 320 dimensions
        f = F.dropout(f, training=self.training) 
        f = F.relu(self.fc1(f)) # We convert 320 dimensions to 50
        f = F.dropout(f, training=self.training) 
        #f = F.relu(self.fc2(f))
        f = self.fc4(f) # We convert 50 dimensions to 20

        return F.log_softmax(x) , F.log_softmax(f)

# %%
network = Net() # Initializing the Neural Network
network = to_device(network, device) # Transferring it to GPU
optimizer = optim.SGD(network.parameters(), lr=learning_rate,
                      momentum=momentum) # Leveraging the Gradient descent optimizer

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*60000 for i in range(n_epochs + 1)]

# %%
def train(epoch):
  network.train() # network.train() sets the model in training mode, which enables features such as dropout and batch normalization.
  additional_train_loader_dataset = 60000 # Train data size
  for training_data in enumerate(additional_train_loader):
    batch_idx = training_data[0] # Splitting the data in the loader to batch, x1 (image data), x2 (random number generated), y1 (number), y2 (sum of y1 and x2)
    image_x1 = training_data[1][0]
    y1 = training_data[1][1]
    x2 = training_data[1][2]
    y2 = training_data[1][3]
    
    optimizer.zero_grad()

    # Converting Float to Int
    x2 = x2.type(torch.LongTensor) 
    y2 = y2.type(torch.LongTensor)
    
    '''
    # One Hot Encoding our inputs
    # Need to convert one hot encoded values to floats. 
    This is needed because the weights are of float datatype. And pytorch requires both matrices being multiplied to have the same datatype

    '''

    x2 = torch.nn.functional.one_hot(x2, num_classes = 20) 
    x2 = x2.to(torch.float32) 

    # Transferring modified inputs to the GPU
    x2 = x2.cuda()
    y2 = y2.cuda()
    output_1, output_2 = network(image_x1, x2) # Passing the image data and one-hot encoded int to the network
    
    y1 = y1.type(torch.LongTensor) # PyTorch won't accept a FloatTensor as categorical target, so need to cast tensor to LongTensor

    y1 = y1.cuda()
    loss_1 = F.nll_loss(output_1, y1) # For Output 1 we calculate negative log likehood loss
    
    output_2 = torch.argmax(output_2, dim=1) # Convert to integer
    
    loss_2 = complex_mse_loss(output_2, y2) # Made a custom function to calculate the mean squared error between output 2 and y2
    # We use this function because the 2 outputs need to be close as in regression
    loss = loss_1 + loss_2 # Calculating the Overall loss
    loss.backward() # Backward Propagation
    optimizer.step()
    if batch_idx % log_interval == 0:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
          epoch, batch_idx * additional_train_loader_dataset, additional_train_loader_dataset,
          100. * batch_idx / len(additional_train_loader), loss.item()))
      train_losses.append(loss.item())
      train_counter.append(
          (batch_idx*64) + ((epoch-1)*additional_train_loader_dataset))
      torch.save(network.state_dict(), '/content/Modified_MNIST_model.pth')
      torch.save(optimizer.state_dict(), '/content/Modified_MNIST_optimizer.pth')

# %%
train(0) 

# for epoch in range(1, n_epochs + 1):
#   train(epoch)
#   # test()
#   print(epoch)

# print(test_counter)
# print(test_losses)

# %%
def test():
  network.eval()
  test_loss = 0
  correct = 0
  additional_train_loader_dataset = 10000
  with torch.no_grad():
    for test_data in enumerate(additional_test_loader):      
      image_x1 = test_data[1][0]
      y1 = test_data[1][1]
      x2 = test_data[1][2]
      y2 = test_data[1][3]

      x2 = x2.type(torch.LongTensor) # Converting Float to Int
      y2 = y2.type(torch.LongTensor)

      x2 = torch.nn.functional.one_hot(x2, num_classes = 20) # One Hot Encoding our inputs
      x2 = x2.to(torch.float32) # Need to convert one hot encoded values to floats. This is needed because the weights are of float datatype. And pytorch requires both matrices being multiplied to have the same datatype

      x2 = x2.cuda()
      y2 = y2.cuda()

      output_1, output_2 = network(image_x1, x2)

      y1 = y1.type(torch.LongTensor) # PyTorch won't accept a FloatTensor as categorical target, so need to cast tensor to LongTensor

      y1 = y1.cuda()
      loss_1 = F.nll_loss(output_1, y1) # For Output 1 we calculate negative log likehood loss
      output_2 = torch.argmax(output_2, dim=1) # Convert to integer
      loss_2 = complex_mse_loss(output_2, y2) # Made a custom function to calculate the mean squared error between output 2 and y2
      loss = loss_1 + loss_2
      test_loss += loss.item()
      pred_1 = output_1.data.max(1, keepdim=True)[1]
      pred_2 = output_2
      correct_1 = pred_1.eq(y1.data.view_as(pred_1)).sum()
      correct_2 = pred_2.eq(y2.data.view_as(pred_2)).sum()
      correct = correct_1 + correct_2
  test_loss /= additional_train_loader_dataset
  test_losses.append(test_loss)
  print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
    test_loss, correct, additional_train_loader_dataset,
    50. * correct / additional_train_loader_dataset)) # 50 because we have 2 values in correct - Correct 1 & Correct 2, to avoid double counting we multiply by 100/2 = 50

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*60000 for i in range(n_epochs + 1)]

# %%
for epoch in range(1, n_epochs + 1):
  train(epoch)
  test()
  print(epoch)

print(test_counter)
print(test_losses)
# Out:
# cuda:0
# Train Epoch: 1 [0/60000 (0%)]	Loss: 6.242949+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 1 [600000/60000 (0%)]	Loss: 14.459955+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 1 [1200000/60000 (0%)]	Loss: 8.933760+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 1 [1800000/60000 (0%)]	Loss: 14.208480+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 1 [2400000/60000 (1%)]	Loss: 11.637441+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 1 [3000000/60000 (1%)]	Loss: 16.321760+0.000000j
# <ipython-input-38-f2dc1ef27b5e>:30: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x) , F.log_softmax(f)
# Streaming output truncated to the last 5000 lines.
# cuda:0
# Train Epoch: 3 [87600000/60000 (24%)]	Loss: 13.905487+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [88200000/60000 (24%)]	Loss: 13.246149+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [88800000/60000 (25%)]	Loss: 15.500585+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [89400000/60000 (25%)]	Loss: 27.593090+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [90000000/60000 (25%)]	Loss: 14.605247+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [90600000/60000 (25%)]	Loss: 19.469624+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [91200000/60000 (25%)]	Loss: 12.616652+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [91800000/60000 (26%)]	Loss: 20.917423+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [92400000/60000 (26%)]	Loss: 17.415224+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [93000000/60000 (26%)]	Loss: 6.283452+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [93600000/60000 (26%)]	Loss: 5.553786+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [94200000/60000 (26%)]	Loss: 13.869197+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [94800000/60000 (26%)]	Loss: 4.317125+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [95400000/60000 (26%)]	Loss: 22.114435+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [96000000/60000 (27%)]	Loss: 17.654121+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [96600000/60000 (27%)]	Loss: 11.592764+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [97200000/60000 (27%)]	Loss: 9.798547+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [97800000/60000 (27%)]	Loss: 7.252360+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [98400000/60000 (27%)]	Loss: 9.824493+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [99000000/60000 (28%)]	Loss: 18.415012+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [99600000/60000 (28%)]	Loss: 19.318769+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [100200000/60000 (28%)]	Loss: 11.116024+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [100800000/60000 (28%)]	Loss: 30.201241+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [101400000/60000 (28%)]	Loss: 18.935179+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [102000000/60000 (28%)]	Loss: 15.376896+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [102600000/60000 (28%)]	Loss: 8.037513+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [103200000/60000 (29%)]	Loss: 11.039192+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [103800000/60000 (29%)]	Loss: 11.703297+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [104400000/60000 (29%)]	Loss: 10.123894+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [105000000/60000 (29%)]	Loss: 4.620982+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [105600000/60000 (29%)]	Loss: 15.501864+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [106200000/60000 (30%)]	Loss: 12.012224+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [106800000/60000 (30%)]	Loss: 10.530104+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [107400000/60000 (30%)]	Loss: 14.201938+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [108000000/60000 (30%)]	Loss: 11.990607+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [108600000/60000 (30%)]	Loss: 12.810308+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [109200000/60000 (30%)]	Loss: 15.351134+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [109800000/60000 (30%)]	Loss: 11.769209+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [110400000/60000 (31%)]	Loss: 20.762897+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [111000000/60000 (31%)]	Loss: 17.882303+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [111600000/60000 (31%)]	Loss: 9.055213+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [112200000/60000 (31%)]	Loss: 11.508943+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [112800000/60000 (31%)]	Loss: 18.680223+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [113400000/60000 (32%)]	Loss: 22.659060+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [114000000/60000 (32%)]	Loss: 8.715514+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [114600000/60000 (32%)]	Loss: 6.394173+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [115200000/60000 (32%)]	Loss: 17.025166+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [115800000/60000 (32%)]	Loss: 16.083853+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [116400000/60000 (32%)]	Loss: 12.506100+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [117000000/60000 (32%)]	Loss: 10.920852+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [117600000/60000 (33%)]	Loss: 15.253966+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [118200000/60000 (33%)]	Loss: 18.043449+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [118800000/60000 (33%)]	Loss: 9.624039+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [119400000/60000 (33%)]	Loss: 19.870338+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [120000000/60000 (33%)]	Loss: 16.691963+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [120600000/60000 (34%)]	Loss: 12.499259+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [121200000/60000 (34%)]	Loss: 14.288431+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [121800000/60000 (34%)]	Loss: 8.960815+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [122400000/60000 (34%)]	Loss: 8.463287+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [123000000/60000 (34%)]	Loss: 11.622622+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [123600000/60000 (34%)]	Loss: 20.281918+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [124200000/60000 (34%)]	Loss: 19.194744+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [124800000/60000 (35%)]	Loss: 8.811231+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [125400000/60000 (35%)]	Loss: 6.098980+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [126000000/60000 (35%)]	Loss: 34.316093+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [126600000/60000 (35%)]	Loss: 4.373295+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [127200000/60000 (35%)]	Loss: 21.845232+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [127800000/60000 (36%)]	Loss: 14.257015+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [128400000/60000 (36%)]	Loss: 10.405857+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [129000000/60000 (36%)]	Loss: 10.405720+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [129600000/60000 (36%)]	Loss: 14.846280+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [130200000/60000 (36%)]	Loss: 9.601765+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [130800000/60000 (36%)]	Loss: 7.599145+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [131400000/60000 (36%)]	Loss: 17.286844+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [132000000/60000 (37%)]	Loss: 12.077570+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [132600000/60000 (37%)]	Loss: 10.711986+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [133200000/60000 (37%)]	Loss: 14.923747+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [133800000/60000 (37%)]	Loss: 8.360422+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [134400000/60000 (37%)]	Loss: 19.526073+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [135000000/60000 (38%)]	Loss: 20.508596+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [135600000/60000 (38%)]	Loss: 9.309553+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [136200000/60000 (38%)]	Loss: 8.618175+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [136800000/60000 (38%)]	Loss: 21.814056+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [137400000/60000 (38%)]	Loss: 11.997787+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [138000000/60000 (38%)]	Loss: 15.147467+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [138600000/60000 (38%)]	Loss: 13.307917+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [139200000/60000 (39%)]	Loss: 8.519110+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [139800000/60000 (39%)]	Loss: 22.888357+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [140400000/60000 (39%)]	Loss: 2.477338+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [141000000/60000 (39%)]	Loss: 13.076980+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [141600000/60000 (39%)]	Loss: 8.348620+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [142200000/60000 (40%)]	Loss: 15.437175+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [142800000/60000 (40%)]	Loss: 27.039391+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [143400000/60000 (40%)]	Loss: 14.570587+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [144000000/60000 (40%)]	Loss: 26.568666+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [144600000/60000 (40%)]	Loss: 11.460458+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [145200000/60000 (40%)]	Loss: 11.199427+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [145800000/60000 (40%)]	Loss: 9.627362+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [146400000/60000 (41%)]	Loss: 16.365183+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [147000000/60000 (41%)]	Loss: 20.465118+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [147600000/60000 (41%)]	Loss: 10.908072+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [148200000/60000 (41%)]	Loss: 4.370483+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [148800000/60000 (41%)]	Loss: 11.522102+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [149400000/60000 (42%)]	Loss: 12.433061+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [150000000/60000 (42%)]	Loss: 10.421120+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [150600000/60000 (42%)]	Loss: 18.492666+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [151200000/60000 (42%)]	Loss: 16.608896+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [151800000/60000 (42%)]	Loss: 17.342138+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [152400000/60000 (42%)]	Loss: 11.067091+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [153000000/60000 (42%)]	Loss: 19.621126+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [153600000/60000 (43%)]	Loss: 7.200658+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [154200000/60000 (43%)]	Loss: 14.201101+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [154800000/60000 (43%)]	Loss: 11.717998+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [155400000/60000 (43%)]	Loss: 4.023309+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [156000000/60000 (43%)]	Loss: 17.392776+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [156600000/60000 (44%)]	Loss: 12.873870+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [157200000/60000 (44%)]	Loss: 19.133930+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [157800000/60000 (44%)]	Loss: 4.158340+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [158400000/60000 (44%)]	Loss: 16.776739+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [159000000/60000 (44%)]	Loss: 9.214616+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [159600000/60000 (44%)]	Loss: 11.909633+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [160200000/60000 (44%)]	Loss: 10.854787+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [160800000/60000 (45%)]	Loss: 15.017042+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [161400000/60000 (45%)]	Loss: 11.523590+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [162000000/60000 (45%)]	Loss: 21.128078+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [162600000/60000 (45%)]	Loss: 10.300745+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [163200000/60000 (45%)]	Loss: 14.939284+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [163800000/60000 (46%)]	Loss: 45.866837+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [164400000/60000 (46%)]	Loss: 10.755265+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [165000000/60000 (46%)]	Loss: 12.533770+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [165600000/60000 (46%)]	Loss: 5.884096+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [166200000/60000 (46%)]	Loss: 15.097698+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [166800000/60000 (46%)]	Loss: 8.802266+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [167400000/60000 (46%)]	Loss: 6.707230+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [168000000/60000 (47%)]	Loss: 7.758690+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [168600000/60000 (47%)]	Loss: 30.856798+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [169200000/60000 (47%)]	Loss: 17.106102+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [169800000/60000 (47%)]	Loss: 12.600127+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [170400000/60000 (47%)]	Loss: 15.253520+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [171000000/60000 (48%)]	Loss: 17.853525+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [171600000/60000 (48%)]	Loss: 15.216583+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [172200000/60000 (48%)]	Loss: 15.005569+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [172800000/60000 (48%)]	Loss: 14.429935+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [173400000/60000 (48%)]	Loss: 14.304168+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [174000000/60000 (48%)]	Loss: 18.924202+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [174600000/60000 (48%)]	Loss: 5.578695+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [175200000/60000 (49%)]	Loss: 23.130020+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [175800000/60000 (49%)]	Loss: 17.429886+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [176400000/60000 (49%)]	Loss: 23.016096+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [177000000/60000 (49%)]	Loss: 8.025710+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [177600000/60000 (49%)]	Loss: 14.709409+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [178200000/60000 (50%)]	Loss: 9.800547+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [178800000/60000 (50%)]	Loss: 4.623585+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [179400000/60000 (50%)]	Loss: 15.025781+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [180000000/60000 (50%)]	Loss: 32.362862+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [180600000/60000 (50%)]	Loss: 15.459923+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [181200000/60000 (50%)]	Loss: 6.006061+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [181800000/60000 (50%)]	Loss: 9.085700+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [182400000/60000 (51%)]	Loss: 6.853518+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [183000000/60000 (51%)]	Loss: 11.450137+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [183600000/60000 (51%)]	Loss: 7.273220+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [184200000/60000 (51%)]	Loss: 30.035643+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [184800000/60000 (51%)]	Loss: 22.253040+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [185400000/60000 (52%)]	Loss: 27.649239+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [186000000/60000 (52%)]	Loss: 7.485545+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [186600000/60000 (52%)]	Loss: 16.127003+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [187200000/60000 (52%)]	Loss: 19.486191+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [187800000/60000 (52%)]	Loss: 14.170377+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [188400000/60000 (52%)]	Loss: 13.890884+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [189000000/60000 (52%)]	Loss: 21.507332+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [189600000/60000 (53%)]	Loss: 19.490360+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [190200000/60000 (53%)]	Loss: 13.757777+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [190800000/60000 (53%)]	Loss: 9.631825+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [191400000/60000 (53%)]	Loss: 7.756958+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [192000000/60000 (53%)]	Loss: 2.778598+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [192600000/60000 (54%)]	Loss: 15.065132+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [193200000/60000 (54%)]	Loss: 21.600185+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [193800000/60000 (54%)]	Loss: 17.106905+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [194400000/60000 (54%)]	Loss: 7.458975+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [195000000/60000 (54%)]	Loss: 7.484045+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [195600000/60000 (54%)]	Loss: 10.221915+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [196200000/60000 (54%)]	Loss: 15.569489+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [196800000/60000 (55%)]	Loss: 12.906177+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [197400000/60000 (55%)]	Loss: 29.761620+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [198000000/60000 (55%)]	Loss: 7.937634+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [198600000/60000 (55%)]	Loss: 6.864837+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [199200000/60000 (55%)]	Loss: 15.272518+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [199800000/60000 (56%)]	Loss: 19.305456+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [200400000/60000 (56%)]	Loss: 14.120422+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [201000000/60000 (56%)]	Loss: 8.506648+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [201600000/60000 (56%)]	Loss: 7.111690+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [202200000/60000 (56%)]	Loss: 18.390572+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [202800000/60000 (56%)]	Loss: 22.366865+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [203400000/60000 (56%)]	Loss: 12.824479+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [204000000/60000 (57%)]	Loss: 6.314019+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [204600000/60000 (57%)]	Loss: 8.603337+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [205200000/60000 (57%)]	Loss: 17.759895+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [205800000/60000 (57%)]	Loss: 9.264326+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [206400000/60000 (57%)]	Loss: 9.590673+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [207000000/60000 (58%)]	Loss: 6.604601+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [207600000/60000 (58%)]	Loss: 18.785915+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [208200000/60000 (58%)]	Loss: 10.232422+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [208800000/60000 (58%)]	Loss: 28.626549+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [209400000/60000 (58%)]	Loss: 12.785979+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [210000000/60000 (58%)]	Loss: 8.635118+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [210600000/60000 (58%)]	Loss: 37.705341+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [211200000/60000 (59%)]	Loss: 17.476950+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [211800000/60000 (59%)]	Loss: 9.839538+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [212400000/60000 (59%)]	Loss: 5.854064+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [213000000/60000 (59%)]	Loss: 6.785609+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [213600000/60000 (59%)]	Loss: 23.623142+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [214200000/60000 (60%)]	Loss: 21.071535+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [214800000/60000 (60%)]	Loss: 18.859432+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [215400000/60000 (60%)]	Loss: 5.701828+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [216000000/60000 (60%)]	Loss: 12.613198+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [216600000/60000 (60%)]	Loss: 9.285478+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [217200000/60000 (60%)]	Loss: 14.580274+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [217800000/60000 (60%)]	Loss: 10.561038+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [218400000/60000 (61%)]	Loss: 32.227310+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [219000000/60000 (61%)]	Loss: 21.558340+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [219600000/60000 (61%)]	Loss: 24.572058+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [220200000/60000 (61%)]	Loss: 12.785009+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [220800000/60000 (61%)]	Loss: 29.107418+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [221400000/60000 (62%)]	Loss: 14.204280+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [222000000/60000 (62%)]	Loss: 19.880909+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [222600000/60000 (62%)]	Loss: 5.550191+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [223200000/60000 (62%)]	Loss: 10.412633+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [223800000/60000 (62%)]	Loss: 8.307010+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [224400000/60000 (62%)]	Loss: 14.474446+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [225000000/60000 (62%)]	Loss: 15.223240+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [225600000/60000 (63%)]	Loss: 4.728505+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [226200000/60000 (63%)]	Loss: 17.460884+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [226800000/60000 (63%)]	Loss: 19.182079+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [227400000/60000 (63%)]	Loss: 15.784838+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [228000000/60000 (63%)]	Loss: 23.819077+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [228600000/60000 (64%)]	Loss: 16.610420+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [229200000/60000 (64%)]	Loss: 14.951939+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [229800000/60000 (64%)]	Loss: 14.297444+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [230400000/60000 (64%)]	Loss: 13.230828+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [231000000/60000 (64%)]	Loss: 30.008919+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [231600000/60000 (64%)]	Loss: 23.879803+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [232200000/60000 (64%)]	Loss: 19.163530+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [232800000/60000 (65%)]	Loss: 12.561905+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [233400000/60000 (65%)]	Loss: 16.170555+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [234000000/60000 (65%)]	Loss: 11.587948+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [234600000/60000 (65%)]	Loss: 31.501688+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [235200000/60000 (65%)]	Loss: 9.915030+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [235800000/60000 (66%)]	Loss: 9.786164+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [236400000/60000 (66%)]	Loss: 15.829351+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [237000000/60000 (66%)]	Loss: 7.804356+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [237600000/60000 (66%)]	Loss: 27.715683+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [238200000/60000 (66%)]	Loss: 13.959040+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [238800000/60000 (66%)]	Loss: 9.249278+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [239400000/60000 (66%)]	Loss: 7.356240+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [240000000/60000 (67%)]	Loss: 15.139398+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [240600000/60000 (67%)]	Loss: 8.600947+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [241200000/60000 (67%)]	Loss: 18.610182+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [241800000/60000 (67%)]	Loss: 17.695433+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [242400000/60000 (67%)]	Loss: 20.278391+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [243000000/60000 (68%)]	Loss: 17.032129+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [243600000/60000 (68%)]	Loss: 19.109316+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [244200000/60000 (68%)]	Loss: 17.634178+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [244800000/60000 (68%)]	Loss: 3.004257+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [245400000/60000 (68%)]	Loss: 14.164722+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [246000000/60000 (68%)]	Loss: 16.171114+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [246600000/60000 (68%)]	Loss: 11.811117+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [247200000/60000 (69%)]	Loss: 4.465527+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [247800000/60000 (69%)]	Loss: 18.962284+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [248400000/60000 (69%)]	Loss: 18.377340+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [249000000/60000 (69%)]	Loss: 11.494824+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [249600000/60000 (69%)]	Loss: 7.459668+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [250200000/60000 (70%)]	Loss: 8.481981+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [250800000/60000 (70%)]	Loss: 34.899967+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [251400000/60000 (70%)]	Loss: 20.710499+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [252000000/60000 (70%)]	Loss: 12.098349+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [252600000/60000 (70%)]	Loss: 23.761408+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [253200000/60000 (70%)]	Loss: 21.651279+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [253800000/60000 (70%)]	Loss: 10.950547+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [254400000/60000 (71%)]	Loss: 23.982492+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [255000000/60000 (71%)]	Loss: 4.760043+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [255600000/60000 (71%)]	Loss: 8.003076+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [256200000/60000 (71%)]	Loss: 20.043192+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [256800000/60000 (71%)]	Loss: 11.327461+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [257400000/60000 (72%)]	Loss: 15.607870+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [258000000/60000 (72%)]	Loss: 25.986736+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [258600000/60000 (72%)]	Loss: 20.370619+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [259200000/60000 (72%)]	Loss: 17.394629+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [259800000/60000 (72%)]	Loss: 15.366390+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [260400000/60000 (72%)]	Loss: 8.967338+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [261000000/60000 (72%)]	Loss: 10.835312+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [261600000/60000 (73%)]	Loss: 8.098602+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [262200000/60000 (73%)]	Loss: 22.333780+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [262800000/60000 (73%)]	Loss: 7.753616+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [263400000/60000 (73%)]	Loss: 10.994974+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [264000000/60000 (73%)]	Loss: 13.755953+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [264600000/60000 (74%)]	Loss: 9.442618+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [265200000/60000 (74%)]	Loss: 22.902441+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [265800000/60000 (74%)]	Loss: 14.118693+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [266400000/60000 (74%)]	Loss: 16.554359+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [267000000/60000 (74%)]	Loss: 26.132463+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [267600000/60000 (74%)]	Loss: 14.768363+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [268200000/60000 (74%)]	Loss: 11.010228+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [268800000/60000 (75%)]	Loss: 17.117682+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [269400000/60000 (75%)]	Loss: 8.891536+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [270000000/60000 (75%)]	Loss: 18.959002+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [270600000/60000 (75%)]	Loss: 16.947653+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [271200000/60000 (75%)]	Loss: 15.800434+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [271800000/60000 (76%)]	Loss: 16.864714+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [272400000/60000 (76%)]	Loss: 14.119724+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [273000000/60000 (76%)]	Loss: 7.429012+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [273600000/60000 (76%)]	Loss: 23.564474+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [274200000/60000 (76%)]	Loss: 4.504798+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [274800000/60000 (76%)]	Loss: 27.759699+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [275400000/60000 (76%)]	Loss: 21.054905+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [276000000/60000 (77%)]	Loss: 17.824345+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [276600000/60000 (77%)]	Loss: 8.868914+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [277200000/60000 (77%)]	Loss: 13.808139+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [277800000/60000 (77%)]	Loss: 11.642286+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [278400000/60000 (77%)]	Loss: 10.438941+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [279000000/60000 (78%)]	Loss: 11.308230+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [279600000/60000 (78%)]	Loss: 14.513507+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [280200000/60000 (78%)]	Loss: 7.841689+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [280800000/60000 (78%)]	Loss: 9.305566+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [281400000/60000 (78%)]	Loss: 15.325542+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [282000000/60000 (78%)]	Loss: 24.680286+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [282600000/60000 (78%)]	Loss: 3.771857+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [283200000/60000 (79%)]	Loss: 12.527433+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [283800000/60000 (79%)]	Loss: 22.354912+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [284400000/60000 (79%)]	Loss: 20.022034+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [285000000/60000 (79%)]	Loss: 11.754449+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [285600000/60000 (79%)]	Loss: 21.713369+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [286200000/60000 (80%)]	Loss: 18.432379+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [286800000/60000 (80%)]	Loss: 8.253067+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [287400000/60000 (80%)]	Loss: 28.563732+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [288000000/60000 (80%)]	Loss: 10.182839+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [288600000/60000 (80%)]	Loss: 19.520107+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [289200000/60000 (80%)]	Loss: 11.602410+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [289800000/60000 (80%)]	Loss: 26.511360+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [290400000/60000 (81%)]	Loss: 23.613329+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [291000000/60000 (81%)]	Loss: 8.389407+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [291600000/60000 (81%)]	Loss: 9.223930+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [292200000/60000 (81%)]	Loss: 27.394678+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [292800000/60000 (81%)]	Loss: 18.586178+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [293400000/60000 (82%)]	Loss: 12.177464+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [294000000/60000 (82%)]	Loss: 12.563938+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [294600000/60000 (82%)]	Loss: 13.065159+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [295200000/60000 (82%)]	Loss: 6.507736+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [295800000/60000 (82%)]	Loss: 6.331590+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [296400000/60000 (82%)]	Loss: 8.854676+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [297000000/60000 (82%)]	Loss: 30.158134+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [297600000/60000 (83%)]	Loss: 26.210655+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [298200000/60000 (83%)]	Loss: 11.540318+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [298800000/60000 (83%)]	Loss: 5.588245+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [299400000/60000 (83%)]	Loss: 28.051159+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [300000000/60000 (83%)]	Loss: 15.219340+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [300600000/60000 (84%)]	Loss: 11.305354+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [301200000/60000 (84%)]	Loss: 15.580383+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [301800000/60000 (84%)]	Loss: 7.107287+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [302400000/60000 (84%)]	Loss: 16.347219+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [303000000/60000 (84%)]	Loss: 24.134420+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [303600000/60000 (84%)]	Loss: 20.062363+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [304200000/60000 (84%)]	Loss: 23.253824+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [304800000/60000 (85%)]	Loss: 15.942791+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [305400000/60000 (85%)]	Loss: 10.511626+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [306000000/60000 (85%)]	Loss: 7.489436+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [306600000/60000 (85%)]	Loss: 13.641681+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [307200000/60000 (85%)]	Loss: 22.688259+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [307800000/60000 (86%)]	Loss: 17.912563+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [308400000/60000 (86%)]	Loss: 32.509506+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [309000000/60000 (86%)]	Loss: 8.510117+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [309600000/60000 (86%)]	Loss: 36.765900+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [310200000/60000 (86%)]	Loss: 14.464114+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [310800000/60000 (86%)]	Loss: 5.773815+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [311400000/60000 (86%)]	Loss: 20.406454+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [312000000/60000 (87%)]	Loss: 17.469791+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [312600000/60000 (87%)]	Loss: 6.620564+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [313200000/60000 (87%)]	Loss: 9.173421+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [313800000/60000 (87%)]	Loss: 18.584892+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [314400000/60000 (87%)]	Loss: 12.783208+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [315000000/60000 (88%)]	Loss: 10.825888+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [315600000/60000 (88%)]	Loss: 17.570925+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [316200000/60000 (88%)]	Loss: 6.700637+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [316800000/60000 (88%)]	Loss: 20.087402+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [317400000/60000 (88%)]	Loss: 10.490603+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [318000000/60000 (88%)]	Loss: 37.044384+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [318600000/60000 (88%)]	Loss: 23.353624+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [319200000/60000 (89%)]	Loss: 13.304662+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [319800000/60000 (89%)]	Loss: 15.499215+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [320400000/60000 (89%)]	Loss: 14.155142+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [321000000/60000 (89%)]	Loss: 7.101492+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [321600000/60000 (89%)]	Loss: 11.197657+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [322200000/60000 (90%)]	Loss: 9.457956+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [322800000/60000 (90%)]	Loss: 16.210291+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [323400000/60000 (90%)]	Loss: 20.821106+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [324000000/60000 (90%)]	Loss: 12.446317+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [324600000/60000 (90%)]	Loss: 19.353773+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [325200000/60000 (90%)]	Loss: 7.837497+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [325800000/60000 (90%)]	Loss: 18.230955+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [326400000/60000 (91%)]	Loss: 6.604220+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [327000000/60000 (91%)]	Loss: 19.155479+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [327600000/60000 (91%)]	Loss: 10.870427+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [328200000/60000 (91%)]	Loss: 17.012625+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [328800000/60000 (91%)]	Loss: 12.910907+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [329400000/60000 (92%)]	Loss: 15.567160+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [330000000/60000 (92%)]	Loss: 11.753868+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [330600000/60000 (92%)]	Loss: 11.679840+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [331200000/60000 (92%)]	Loss: 5.200928+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [331800000/60000 (92%)]	Loss: 28.253235+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [332400000/60000 (92%)]	Loss: 25.281376+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [333000000/60000 (92%)]	Loss: 24.996065+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [333600000/60000 (93%)]	Loss: 6.606135+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [334200000/60000 (93%)]	Loss: 37.558483+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [334800000/60000 (93%)]	Loss: 7.310554+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [335400000/60000 (93%)]	Loss: 9.819569+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [336000000/60000 (93%)]	Loss: 10.065153+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [336600000/60000 (94%)]	Loss: 3.810361+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [337200000/60000 (94%)]	Loss: 7.624180+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [337800000/60000 (94%)]	Loss: 8.360316+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [338400000/60000 (94%)]	Loss: 14.122962+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [339000000/60000 (94%)]	Loss: 17.508764+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [339600000/60000 (94%)]	Loss: 12.228091+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [340200000/60000 (94%)]	Loss: 3.102369+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [340800000/60000 (95%)]	Loss: 13.180203+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [341400000/60000 (95%)]	Loss: 20.225258+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [342000000/60000 (95%)]	Loss: 16.657310+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [342600000/60000 (95%)]	Loss: 9.721685+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [343200000/60000 (95%)]	Loss: 16.355453+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [343800000/60000 (96%)]	Loss: 16.261963+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [344400000/60000 (96%)]	Loss: 27.227802+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [345000000/60000 (96%)]	Loss: 8.574877+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [345600000/60000 (96%)]	Loss: 14.800839+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [346200000/60000 (96%)]	Loss: 13.170039+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [346800000/60000 (96%)]	Loss: 16.514254+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [347400000/60000 (96%)]	Loss: 9.822931+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [348000000/60000 (97%)]	Loss: 2.761474+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [348600000/60000 (97%)]	Loss: 8.946777+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [349200000/60000 (97%)]	Loss: 12.653773+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [349800000/60000 (97%)]	Loss: 16.841694+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [350400000/60000 (97%)]	Loss: 12.996747+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [351000000/60000 (98%)]	Loss: 12.781171+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [351600000/60000 (98%)]	Loss: 20.053335+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [352200000/60000 (98%)]	Loss: 9.037141+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [352800000/60000 (98%)]	Loss: 12.836564+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [353400000/60000 (98%)]	Loss: 17.660751+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [354000000/60000 (98%)]	Loss: 7.975650+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [354600000/60000 (98%)]	Loss: 8.559664+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [355200000/60000 (99%)]	Loss: 16.970644+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [355800000/60000 (99%)]	Loss: 18.555664+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [356400000/60000 (99%)]	Loss: 15.550825+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [357000000/60000 (99%)]	Loss: 12.214651+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [357600000/60000 (99%)]	Loss: 6.465926+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [358200000/60000 (100%)]	Loss: 8.062404+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [358800000/60000 (100%)]	Loss: 12.683304+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Train Epoch: 3 [359400000/60000 (100%)]	Loss: 23.537781+0.000000j
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
#
# Test set: Avg. loss: 0.0085+0.0000j, Accuracy: 1090/10000 (5%)
#
# 3
# [0, 60000, 120000, 180000]
# [(0.008513452434539794+0j), (0.008505743408203125+0j), (0.008501232147216797+0j)]

# %%
# After 3 Epochs the test accuracy is at only 5%, perhaps this improves as we increase the number of epochs
